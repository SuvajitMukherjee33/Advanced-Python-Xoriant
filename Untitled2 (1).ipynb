# %%
#passing function as argument
def outer(f):  #2
    def inner():  #4
        result=f()  #5
        return result **2
    return inner  #3
#calling
def num():
    return 5
r=outer(num)
r()
# Out:
# 25

# %%
def validate(func):
    def validator(*args,**kwargs):
        if len(args>)1:
            if args[1]==0:
