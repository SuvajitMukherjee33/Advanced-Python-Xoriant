# %%
emp_info={}
while True:
    print("1.Create employee records")
    print("2.Update employee details")
    print("3.Delete employee record")
    print("4.Display")
    print("5.Exit")
    
    ch=int(input("Enter your choice"))
    if ch==1:
        name=input("Enter Employee name:")
        emp_id=int(input("Enter Employee id:"))
        ph=input("Enter phone number:")
        tech=input("Technologies[comma seperated eg:cpp,python,.net]")
        emp_info[emp_id]={"Name":name,"Phone":ph,'tech':tech.split(,)}
        
    elif ch==2:
        who=int(input("Whoes detailes ypu want to update:, pls enter employee id"))
        rec=emp_info[who]
        for field, value in rec.items():
            new=input('{}({})'.format(field,value)}
            emp_info[who][field]=value if new=='' else new
    
    elif ch==3:
        who=int(input("Enter employee id to delete record"))
        del_emp_info[who]
        print("Deleted")
    elif ch==4:
        print(emp_info)
    else:
        break

# %%
lit=[2,3,4.5,6]
lit
